# %% [markdown]
# # **CONCLUSION**

# %% [markdown]
# ![BIKE RENTAL GROWTH TREND.png](data:image/png;base64,...)

# %% [markdown]
# The bike-sharing rental process is highly correlated to the environmental and seasonal settings. For instance, weather conditions, precipitation, day of the week, season, an hour of the day, etc. can affect the rental behaviors. The core data set is related to the two-year historical log corresponding to the years 2011 and 2012 from **Capital Bikeshare** system. From our research, we found that there are increase in number for bike-sharing rental from year 2011 to year 2012.

# %% [markdown]
# ![CASUAL USER GROWTH.png](data:image/png;base64,...) <BR> <BR>
# ![REGISTERED USER GROWTH.png](data:image/png;base64,...)

# %% [markdown]
# The user of bike-sharing rental is expanding. From the data given, we can see that there is a good opportuninty for inceasing revenue from switching the casual user to registered user in March - September. Because the number of casual user is elevate in these months.

# %% [markdown]
# ![CASUAL USER DAILY BEHAVIOUR.png](data:image/png;base64,...)<BR><BR>
# ![REGISTERED USER DAILY BEHAVIOUR.png](data:image/png;base64,...)

# %% [markdown]
# For the behaviour of each user, as we can see from the graph above, Casual user tend to use bike-sharing in weekend (saturday and sunday) during daylight. Which means, we have to pay attention to bike unit stock in weekend as the number of casual user might increase beyond our prediction. This matter can be caused by external features that we do not know and include in our modeling (such as event, promotion and so on). Meanwhile for registered user is more likely being used by office worker during commute hour. We suggest that there should be a marketing strategy using that behaviour.

# %% [markdown]
# ![WhatsApp Image 2021-07-24 at 14.46.48.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# After trying and comparing several model, we decide to use CatBoost for our machine learning model. Because when compared to other model (linear regression, Random Forest and XGBoost), the score is better than other (MAE score is lower and R2 score is higher). This model parameter already being hyper parameter tuned and cross validation.
#
#
# Our model seems to fit the pattern as we can see from the graph. Because of the trend of bike-sharing rental is increasing from year 2011 to year 2012, we do not random split our dataset when creating the model. For every prediction that is above the actual, as we concern it is as okay as long as the number still in the interval range. Because when we supply a little bit more, it can be used as spare for undetected broken bike (such as flat tire or else). Also it can manage to adjust the increase of user that is not affected by features we include in this modeling

# %% [markdown]
# # **RECOMMENDATION**

# %% [markdown]
# For next development, we suggest to add more features for example duration of bike-sharing rental used, start-end position of bikes.

# %% [markdown]
# # **CITATION**

# %% [markdown]
# * Predicting Intervals <br>
# https://machinelearningmastery.com/prediction-intervals-for-machine-learning/ <br>
#
# * Hyper Parameter Tuning <br>
# https://www.kaggle.com/felipefiorini/xgboost-hyper-parameter-tuning <br>
#
# * XGBoost <br>
# https://towardsdatascience.com/beyond-grid-search-hypercharge-hyperparameter-tuning-for-xgboost-7c78f7a2929d <br>
#
# * Cross Validation <br>
# https://medium.com/analytics-vidhya/introduction-to-cross-validation-k-fold-7ed9cbd0ed7b <br>
