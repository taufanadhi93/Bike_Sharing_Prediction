# %% [markdown]
# # **DATA UNDERSTANDING**

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
dataExplanation = pd.read_excel('/content/gdrive/MyDrive/Biker Sharing /# Final Project/Dataset/Dataset Library.xlsx', sheet_name='Attributes Information')
overview_stat = pd.read_excel('/content/gdrive/MyDrive/Biker Sharing /# Final Project/Dataset/Dataset Library.xlsx', sheet_name='Data Statistics')
overview = pd.read_excel('/content/gdrive/MyDrive/Biker Sharing /# Final Project/Dataset/Dataset Library.xlsx', sheet_name='Data Type')

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### **DATA SOURCE**

# %% [markdown]
# All data is available at https://www.kaggle.com/marklvl/bike-sharing-dataset

# %% [markdown]
# ### **DATA OVERVIEW**

# %%
overview_stat
# Out:
#          Data Statistics   Count
# 0     Number of variable      17
# 1  Number of observation   17379
# 2             Numerical       16
# 3            Categorical       1
# 4           Missing cell       0
# 5          Duplicate row       0
# 6     Total memory usege  2.3 Mb

# %%
overview
# Out:
#       Features Data type Null %  Disctinct %                       Descriptions
# 0      instant     int64    0 %     1.000000                    Number of index
# 1       dteday    object    0 %     1.000000                     Number of date
# 2       season     int64    0 %     0.250000                   Number of season
# 3           yr     int64    0 %     0.500000                     Number of year
# 4         mnth     int64    0 %     0.833333                    Number of month
# 5           hr     int64    0 %     0.041600                     Number of hour
# 6      holiday     int64    0 %     0.500000                  Number of Holiday
# 7      weekday     int64    0 %     0.142800                  Number of weekday
# 8   workingday     int64    0 %     0.500000              Number of working day
# 9   weathersit     int64    0 %     0.250000                  Weather condition
# 10        temp   float64    0 %     0.020000              Temperature condition
# ...

# %% [markdown]
# ### **COLUMNS EXPLANATIONS**

# %%
dataExplanation
# Out:
#        Columns                                                                                                                                                                                                                                                                                            Description
# 0      instant                                                                                                                                                                                                                                                                                           Record index
# 1       dteday                                                                                                                                                                                                                                                                                                   Date
# ...

# %% [markdown]
# ###**ACKNOWLEDGEMENT**

# %% [markdown]
# Hadi Fanaee-T
# Laboratory of Artificial Intelligence and Decision Support (LIAAD), University of Porto
# INESC Porto, Campus da FEUP
# Rua Dr. Roberto Frias, 378
# 4200 - 465 Porto, Portugal
#
# Original Source: http://capitalbikeshare.com/system-data
#
# Weather Information: http://www.freemeteo.com
#
# Holiday Schedule: http://dchr.dc.gov/page/holiday-schedule
